# %%
import newspaper 
import bs4 as bs
import requests
import spacy
import re
import pandas as pd
import numpy as np
from keras.preprocessing.sequence import pad_sequences
# Out:
# Using TensorFlow backend.

# %%
nlp = spacy.load('en')

# %%
def tokenize(sent):
    return [x.strip() for x in re.split('(\W+)?', sent) if x.strip()]

# %%
# Top Tech Companies
ticker_tech_comp = ['GOOG', "AMZN", "FB", "AAPL", "MSFT"]
tech_comp = ["google","amazon","facebook","apple","microsoft"]

# %%
# Prevents caching so that all articles are released
techcrunch_paper = newspaper.build('https://techcrunch.com/', memoize_articles=False) # memoize looks wrong but its not

# %%
for article in techcrunch_paper.articles:
    print(article.url)
# Out:
# http://techcrunch.cn/2017/06/13/emil-michael-ubers-svp-of-business-has-left-the-company/?ncid=rss
# http://techcrunch.cn/2017/06/13/emil-michael-ubers-svp-of-business-has-left-the-company/
# http://techcrunch.cn/2017/06/13/emil-michael-ubers-svp-of-business-has-left-the-company/feed/
# http://techcrunch.cn/2017/06/13/comscore-cord-cutters-tend-to-have-lower-incomes-than-pay-tv-subscribers-watch-less-television/?ncid=rss
# http://techcrunch.cn/2017/06/13/comscore-cord-cutters-tend-to-have-lower-incomes-than-pay-tv-subscribers-watch-less-television/
# http://techcrunch.cn/2017/06/13/comscore-cord-cutters-tend-to-have-lower-incomes-than-pay-tv-subscribers-watch-less-television/feed/
# http://techcrunch.cn/2017/06/05/toyotas-flying-car-project-takes-a-tentative-test-flight/?ncid=rss
# http://techcrunch.cn/2017/06/05/toyotas-flying-car-project-takes-a-tentative-test-flight/
# http://techcrunch.cn/2017/06/05/toyotas-flying-car-project-takes-a-tentative-test-flight/feed/
# http://techcrunch.cn/2017/06/02/us-approves-social-media-background-checks-for-visa-applicants/?ncid=rss
# http://techcrunch.cn/2017/06/02/us-approves-social-media-background-checks-for-visa-applicants/
# http://techcrunch.cn/2017/06/02/us-approves-social-media-background-checks-for-visa-applicants/feed/
# http://techcrunch.cn/2017/06/02/onelogin-admits-recent-breach-is-pretty-dang-serious/?ncid=rss
# http://techcrunch.cn/2017/06/02/onelogin-admits-recent-breach-is-pretty-dang-serious/
# http://techcrunch.cn/2017/06/02/onelogin-admits-recent-breach-is-pretty-dang-serious/feed/
# http://techcrunch.cn/2017/06/02/dji-spark-review/?ncid=rss
# http://techcrunch.cn/2017/06/02/dji-spark-review/
# http://techcrunch.cn/2017/06/02/dji-spark-review/feed/
# http://techcrunch.cn/2017/06/02/tc-shenzhen-2017-we-young/?ncid=rss
# http://techcrunch.cn/2017/06/02/tc-shenzhen-2017-we-young/
# http://techcrunch.cn/2017/06/02/tc-shenzhen-2017-we-young/feed/
# http://techcrunch.cn/2017/06/01/internet-trends-2017/?ncid=rss
# http://techcrunch.cn/2017/06/01/internet-trends-2017/
# http://techcrunch.cn/2017/06/01/internet-trends-2017/feed/
# http://techcrunch.cn/2017/06/01/ntt-data-announces-strategic-investment-in-nosql-database-provider-marklogic/?ncid=rss
# http://techcrunch.cn/2017/06/01/ntt-data-announces-strategic-investment-in-nosql-database-provider-marklogic/
# http://techcrunch.cn/2017/06/01/ntt-data-announces-strategic-investment-in-nosql-database-provider-marklogic/feed/
# http://techcrunch.cn/2017/05/27/mozilla-2017-goal-for-a-healthy-internet/?ncid=rss
# http://techcrunch.cn/2017/05/27/mozilla-2017-goal-for-a-healthy-internet/
# http://techcrunch.cn/2017/05/27/mozilla-2017-goal-for-a-healthy-internet/feed/
# http://jp.techcrunch.com/2015/06/25/20150624nobook-messenger/comment-page-1/
# http://jp.techcrunch.com/2014/10/13/20141011edward-snowden-new-yorker-festival/comment-page-1/
# http://jp.techcrunch.com/2014/10/10/jp20141010ring/comment-page-1/
# http://jp.techcrunch.com/2014/09/10/20140909up-close-and-personal-with-the-iphone-6-and-6-plus-on-video/comment-page-1/
# http://jp.techcrunch.com/2014/09/05/20140904apple-will-live-stream-the-iphone-event-on-september-9/comment-page-1/
# http://jp.techcrunch.com/2014/09/05/20140904the-garmin-vivosmart-is-part-activity-tracker-and-part-smartwatch/comment-page-1/
# http://jp.techcrunch.com/2014/08/27/20140824man-builds-a-suit-to-turn-himself-into-a-human-fireworks-display-lives/comment-page-1/
# http://jp.techcrunch.com/2014/05/17/20140516the-app-store-is-proof-were-in-idiocracy/comment-page-1/
# http://jp.techcrunch.com/2014/04/22/tcjp-thisweek-4014-420/comment-page-1/
# http://jp.techcrunch.com/2013/11/21/20131120googles-cerf-says-privacy-may-be-an-anomaly-historically-hes-right/comment-page-1/
# http://techcrunch.cn/2013/08/01/google-launches-new-ad-unit-for-responsive-sites/comment-page-1/
# http://techcrunch.cn/2014/11/21/salesforce-slips-on-weak-guidance-despite-beating-on-both-revenue-and-profit-in-its-fq3/comment-page-1/
# http://techcrunch.cn/2015/03/29/15-techcrunch-stories-you-dont-want-to-miss-this-week-3/comment-page-1/
# http://techcrunch.cn/2015/03/27/mozilla-extends-its-default-google-search-blockout-signs-up-yandex-in-turkey/comment-page-1/
# http://techcrunch.cn/2015/03/27/reddit-embeddable-comments/comment-page-1/
# http://techcrunch.cn/2015/02/15/deezer-takes-its-high-def-elite-service-global-in-sonos-partnership/comment-page-1/
# http://techcrunch.cn/2014/12/22/maxthon-nitro/comment-page-1/
# http://techcrunch.cn/2014/11/11/pi-model-a-plus/comment-page-1/
# http://techcrunch.cn/2014/10/28/snapdeal-india-softbank/comment-page-1/
# https://techcrunch.com/2006/05/17/feeds-20-a-little-like-searchfox/?ncid=rss
# http://jp.techcrunch.com/2017/06/22/20170621facebook-open-sources-its-it-management-tool-for-distributing-adobes-creative-cloud-tools-to-employees/
# http://jp.techcrunch.com/2017/06/22/20170621facebook-open-sources-its-it-management-tool-for-distributing-adobes-creative-cloud-tools-to-employees/feed/
# http://jp.techcrunch.com/2017/06/22/20170621chinas-tantan-raises-70-million/
# http://jp.techcrunch.com/2017/06/22/20170621chinas-tantan-raises-70-million/feed/
# http://jp.techcrunch.com/2017/06/22/20170621re2-tapped-by-u-s-air-force-to-build-robot-pilots-to-fly-traditional-aircraft/
# http://jp.techcrunch.com/2017/06/22/20170621re2-tapped-by-u-s-air-force-to-build-robot-pilots-to-fly-traditional-aircraft/feed/
# http://jp.techcrunch.com/2017/06/22/20170621snapchat-buys-zenly/
# http://jp.techcrunch.com/2017/06/22/20170621snapchat-buys-zenly/feed/
# http://jp.techcrunch.com/2017/06/22/20170621facebook-is-testing-a-feature-to-prevent-profile-pictures-being-abused-by-other-users/
# http://jp.techcrunch.com/2017/06/22/20170621facebook-is-testing-a-feature-to-prevent-profile-pictures-being-abused-by-other-users/feed/
# http://jp.techcrunch.com/2017/06/22/eight-corporate-page/
# http://jp.techcrunch.com/2017/06/22/eight-corporate-page/feed/
# http://jp.techcrunch.com/2017/06/22/20170620apple-releases-new-iphone-ad-focused-on-the-memories-feature/
# http://jp.techcrunch.com/2017/06/22/20170620apple-releases-new-iphone-ad-focused-on-the-memories-feature/feed/
# http://jp.techcrunch.com/2017/06/22/20170621textio-20m/
# http://jp.techcrunch.com/2017/06/22/20170621textio-20m/feed/
# http://jp.techcrunch.com/2017/06/22/20170621segas-new-sega-forever-collection-brings-classic-games-to-mobile-for-free/
# http://jp.techcrunch.com/2017/06/22/20170621segas-new-sega-forever-collection-brings-classic-games-to-mobile-for-free/feed/
# http://jp.techcrunch.com/2017/06/22/20170621watch-former-apple-engineers-and-scott-forstall-discuss-the-creation-of-the-iphone/
# http://jp.techcrunch.com/2017/06/22/20170621watch-former-apple-engineers-and-scott-forstall-discuss-the-creation-of-the-iphone/feed/
# http://techcrunch.com/2016/03/14/watch-us-beat-the-heck-out-of-each-other-in-disneys-new-fighter-marvel-battlegrounds/
# http://techcrunch.com/2016/03/11/nasas-next-mars-mission-scheduled-for-may-2018/
# http://techcrunch.com/2016/03/10/americans-think-most-human-jobs-could-be-automated-by-2065-finds-pew/
# http://techcrunch.com/2016/03/17/airmada-poised-to-show-their-automated-drone-concept-at-y-combinator-demo-day/?ncid=rss&amp;utm_source=feedburner&amp;utm_medium=feed&amp;utm_campaign=Feed%3A+Techcrunch+%28TechCrunch%29&amp;sr_share=twitter
# http://techcrunch.com/2016/04/25/hundreds-of-spotify-credentials-appear-online-users-report-accounts-hacked-emails-changed/
# http://techcrunch.com/2016/04/25/university-of-florida-held-the-worlds-first-brain-controlled-drone-race/
# http://techcrunch.com/2016/04/19/the-first-comprehensive-study-on-women-in-venture-capital/
# http://techcrunch.com/2016/04/20/leeco-concept-car/
# http://techcrunch.com/2016/04/19/all-your-bots-are-belong-to-us/
# http://techcrunch.com/2016/04/21/facebook-news-is-new/
# http://techcrunch.com/2016/04/20/you-print-me-right-round-baby-right-round/
# http://techcrunch.com/2016/03/28/review-the-oculus-rift/
# http://techcrunch.com/2016/04/05/review-htc-vive/
# http://techcrunch.com/2015/04/08/three-days-in-the-absolutely-insane-tesla-model-s-p85d/
# http://techcrunch.com/2016/03/23/tesla-is-now-offering-ludicrous-mode-upgrades-for-older-p90d-models-because-why-not/
# http://techcrunch.com/2016/03/28/kuvee-raises-6-million-for-smart-wine-bottles/
# http://techcrunch.com/2016/03/30/so-many-windows/
# http://techcrunch.com/2016/03/29/jeff-buckley-just-like-a-woman/?ncid=rss&amp;utm_source=feedburner&amp;utm_medium=feed&amp;utm_campaign=Feed%3A+Techcrunch+%28TechCrunch%29&amp;sr_share=twitter
# https://techcrunch.com/2017/06/21/jd-com-invests-397m-into-luxury-marketplace-farfetch-as-part-of-a-new-strategic-partnership/?ncid=rss
# https://techcrunch.com/2017/06/21/jd-com-invests-397m-into-luxury-marketplace-farfetch-as-part-of-a-new-strategic-partnership/
# https://techcrunch.com/2017/06/21/jd-com-invests-397m-into-luxury-marketplace-farfetch-as-part-of-a-new-strategic-partnership/feed/
# https://techcrunch.com/2017/06/21/chinas-tantan-raises-70-million/?ncid=rss
# https://techcrunch.com/2017/06/21/chinas-tantan-raises-70-million/
# https://techcrunch.com/2017/06/21/chinas-tantan-raises-70-million/feed/
# https://techcrunch.com/2017/06/21/mercari-hires-john-lagerling-from-facebooks-management-team-to-guide-its-u-s-strategy/?ncid=rss
# https://techcrunch.com/2017/06/21/mercari-hires-john-lagerling-from-facebooks-management-team-to-guide-its-u-s-strategy/
# https://techcrunch.com/2017/06/21/mercari-hires-john-lagerling-from-facebooks-management-team-to-guide-its-u-s-strategy/feed/
# https://techcrunch.com/2017/06/21/regulation-could-stifle-growing-china-us-venture-activity/?ncid=rss
# https://techcrunch.com/2017/06/21/regulation-could-stifle-growing-china-us-venture-activity/
# https://techcrunch.com/2017/06/21/regulation-could-stifle-growing-china-us-venture-activity/feed/
# https://techcrunch.com/2017/06/20/mobike-cto-joe-xia-techcrunch-china-shenzhen/?ncid=rss
# https://techcrunch.com/2017/06/20/mobike-cto-joe-xia-techcrunch-china-shenzhen/
# https://techcrunch.com/2017/06/20/mobike-cto-joe-xia-techcrunch-china-shenzhen/feed/
# https://techcrunch.com/2017/06/20/kik-ceo-claims-an-ico-is-better-than-venture-fundraising/?ncid=rss
# https://techcrunch.com/2017/06/20/kik-ceo-claims-an-ico-is-better-than-venture-fundraising/
# https://techcrunch.com/2017/06/20/kik-ceo-claims-an-ico-is-better-than-venture-fundraising/feed/
# https://techcrunch.com/2017/06/20/all-roads-lead-to-shenzhen/?ncid=rss
# https://techcrunch.com/2017/06/20/all-roads-lead-to-shenzhen/
# https://techcrunch.com/2017/06/20/all-roads-lead-to-shenzhen/feed/
# https://techcrunch.com/2017/06/20/hike-messenger-payments-india/?ncid=rss
# https://techcrunch.com/2017/06/20/hike-messenger-payments-india/
# https://techcrunch.com/2017/06/20/hike-messenger-payments-india/feed/
# https://techcrunch.com/2017/06/19/fritz-demopoulos-commitment/?ncid=rss
# https://techcrunch.com/2017/06/19/fritz-demopoulos-commitment/
# https://techcrunch.com/2017/06/19/fritz-demopoulos-commitment/feed/
# https://techcrunch.com/2017/06/19/meltwater-acquires-hong-kong-based-klarity-to-boost-social-media-monitoring-in-asia/?ncid=rss
# https://techcrunch.com/2017/06/19/meltwater-acquires-hong-kong-based-klarity-to-boost-social-media-monitoring-in-asia/
# https://techcrunch.com/2017/06/19/meltwater-acquires-hong-kong-based-klarity-to-boost-social-media-monitoring-in-asia/feed/
# https://techcrunch.com/2017/06/19/can-hong-kong-become-a-startup-hub/?ncid=rss
# https://techcrunch.com/2017/06/19/can-hong-kong-become-a-startup-hub/
# https://techcrunch.com/2017/06/19/can-hong-kong-become-a-startup-hub/feed/
# https://techcrunch.com/2017/06/19/will-amazon-become-a-force-in-fintech/?ncid=rss
# https://techcrunch.com/2017/06/19/will-amazon-become-a-force-in-fintech/
# https://techcrunch.com/2017/06/19/will-amazon-become-a-force-in-fintech/feed/
# https://techcrunch.com/2017/06/15/alibaba-is-in-talks-to-invest-in-ubers-southeast-asia-rival-grab/?ncid=rss
# https://techcrunch.com/2017/06/15/alibaba-is-in-talks-to-invest-in-ubers-southeast-asia-rival-grab/
# https://techcrunch.com/2017/06/15/alibaba-is-in-talks-to-invest-in-ubers-southeast-asia-rival-grab/feed/
# https://techcrunch.com/2017/06/15/mobike-raises-600-million/?ncid=rss
# https://techcrunch.com/2017/06/15/mobike-raises-600-million/
# https://techcrunch.com/2017/06/15/mobike-raises-600-million/feed/
# https://techcrunch.com/2017/06/15/mobikwik-raising-100-150-million-at-1-billion-valuation/?ncid=rss
# https://techcrunch.com/2017/06/15/mobikwik-raising-100-150-million-at-1-billion-valuation/
# https://techcrunch.com/2017/06/15/mobikwik-raising-100-150-million-at-1-billion-valuation/feed/
# https://techcrunch.com/2017/06/14/500-startups-35-million-japan-fund/?ncid=rss
# https://techcrunch.com/2017/06/14/500-startups-35-million-japan-fund/
# https://techcrunch.com/2017/06/14/500-startups-35-million-japan-fund/feed/
# https://techcrunch.com/2017/06/13/man-in-pakistan-sentenced-to-death-for-blasphemous-facebook-comments/?ncid=rss
# https://techcrunch.com/2017/06/13/man-in-pakistan-sentenced-to-death-for-blasphemous-facebook-comments/
# https://techcrunch.com/2017/06/13/man-in-pakistan-sentenced-to-death-for-blasphemous-facebook-comments/feed/
# https://techcrunch.com/2017/06/12/intudo-ventures-launches-10m-fund-for-indonesias-fast-growing-startup-ecosystem/?ncid=rss
# https://techcrunch.com/2017/06/12/intudo-ventures-launches-10m-fund-for-indonesias-fast-growing-startup-ecosystem/
# https://techcrunch.com/2017/06/12/intudo-ventures-launches-10m-fund-for-indonesias-fast-growing-startup-ecosystem/feed/
# https://techcrunch.com/2017/06/12/grab-is-assisting-police-following-the-alleged-rape-of-a-passenger-in-malaysia/?ncid=rss
# https://techcrunch.com/2017/06/12/grab-is-assisting-police-following-the-alleged-rape-of-a-passenger-in-malaysia/
# https://techcrunch.com/2017/06/12/grab-is-assisting-police-following-the-alleged-rape-of-a-passenger-in-malaysia/feed/
# https://techcrunch.com/2017/06/09/thailand-jails-man-for-35-years-for-facebook-posts-that-insulted-its-royal-family/?ncid=rss
# https://techcrunch.com/2017/06/09/thailand-jails-man-for-35-years-for-facebook-posts-that-insulted-its-royal-family/
# https://techcrunch.com/2017/06/09/thailand-jails-man-for-35-years-for-facebook-posts-that-insulted-its-royal-family/feed/
# https://techcrunch.com/2017/06/22/elastic-enters-apm-space-with-opbeat-acquisition/?ncid=rss
# https://techcrunch.com/2017/06/22/elastic-enters-apm-space-with-opbeat-acquisition/
# https://techcrunch.com/2017/06/22/elastic-enters-apm-space-with-opbeat-acquisition/feed/
# https://techcrunch.com/2017/06/22/sean-parker-has-left-spotifys-board-padmasree-warrior-thomas-staggs-join-in-lead-up-to-ipo/?ncid=rss
# https://techcrunch.com/2017/06/22/sean-parker-has-left-spotifys-board-padmasree-warrior-thomas-staggs-join-in-lead-up-to-ipo/
# https://techcrunch.com/2017/06/22/sean-parker-has-left-spotifys-board-padmasree-warrior-thomas-staggs-join-in-lead-up-to-ipo/feed/
# https://techcrunch.com/2017/06/22/sign-up-for-2-4-1-tickets-to-disrupt-berlin-by-june-29/?ncid=rss
# https://techcrunch.com/2017/06/22/sign-up-for-2-4-1-tickets-to-disrupt-berlin-by-june-29/
# https://techcrunch.com/2017/06/22/sign-up-for-2-4-1-tickets-to-disrupt-berlin-by-june-29/feed/
# https://techcrunch.com/2017/06/22/aproplan/?ncid=rss
# https://techcrunch.com/2017/06/22/aproplan/
# https://techcrunch.com/2017/06/22/aproplan/feed/
# https://techcrunch.com/2017/06/21/facebook-is-testing-a-feature-to-prevent-profile-pictures-being-abused-by-other-users/?ncid=rss
# https://techcrunch.com/2017/06/21/facebook-is-testing-a-feature-to-prevent-profile-pictures-being-abused-by-other-users/
# https://techcrunch.com/2017/06/21/facebook-is-testing-a-feature-to-prevent-profile-pictures-being-abused-by-other-users/feed/
# https://techcrunch.com/2017/06/21/etsy-will-cut-15-percent-of-its-workforce-in-a-new-round-of-layoffs/?ncid=rss
# https://techcrunch.com/2017/06/21/etsy-will-cut-15-percent-of-its-workforce-in-a-new-round-of-layoffs/
# https://techcrunch.com/2017/06/21/etsy-will-cut-15-percent-of-its-workforce-in-a-new-round-of-layoffs/feed/
# https://techcrunch.com/2017/06/21/kalanick-is-out-but-ubers-vcs-royally-screwed-up-too-say-industry-watchers/?ncid=rss
# https://techcrunch.com/2017/06/21/kalanick-is-out-but-ubers-vcs-royally-screwed-up-too-say-industry-watchers/
# https://techcrunch.com/2017/06/21/kalanick-is-out-but-ubers-vcs-royally-screwed-up-too-say-industry-watchers/feed/
# https://techcrunch.com/2017/06/21/bill-gurley-to-leave-ubers-board-of-directors/?ncid=rss
# https://techcrunch.com/2017/06/21/bill-gurley-to-leave-ubers-board-of-directors/
# https://techcrunch.com/2017/06/21/bill-gurley-to-leave-ubers-board-of-directors/feed/
# https://techcrunch.com/2017/06/21/crunch-report-uber-ceo-travis-kalanick-resigns/?ncid=rss
# https://techcrunch.com/2017/06/21/crunch-report-uber-ceo-travis-kalanick-resigns/
# https://techcrunch.com/2017/06/21/crunch-report-uber-ceo-travis-kalanick-resigns/feed/
# https://techcrunch.com/2017/06/21/international-entrepreneur-rule-delay-or-rescind/?ncid=rss
# https://techcrunch.com/2017/06/21/international-entrepreneur-rule-delay-or-rescind/
# https://techcrunch.com/2017/06/21/international-entrepreneur-rule-delay-or-rescind/feed/
# https://techcrunch.com/2017/06/21/russian-freight-service-deliver-closes-seed-round-of-8m-with-european-plans/?ncid=rss
# https://techcrunch.com/2017/06/21/russian-freight-service-deliver-closes-seed-round-of-8m-with-european-plans/
# https://techcrunch.com/2017/06/21/russian-freight-service-deliver-closes-seed-round-of-8m-with-european-plans/feed/
# https://techcrunch.com/2017/06/21/google-glass-is-apparently-still-around-and-just-got-its-first-update-in-nearly-three-years/?ncid=rss
# https://techcrunch.com/2017/06/21/google-glass-is-apparently-still-around-and-just-got-its-first-update-in-nearly-three-years/
# https://techcrunch.com/2017/06/21/google-glass-is-apparently-still-around-and-just-got-its-first-update-in-nearly-three-years/feed/
# https://techcrunch.com/2017/06/21/how-technology-enabled-selves-improvement-will-drive-the-future-of-personal-productivity/?ncid=rss
# https://techcrunch.com/2017/06/21/how-technology-enabled-selves-improvement-will-drive-the-future-of-personal-productivity/
# https://techcrunch.com/2017/06/21/how-technology-enabled-selves-improvement-will-drive-the-future-of-personal-productivity/feed/
# https://techcrunch.com/2017/06/21/apple-goes-after-clones-and-spam-on-the-app-store/?ncid=rss
# https://techcrunch.com/2017/06/21/apple-goes-after-clones-and-spam-on-the-app-store/
# https://techcrunch.com/2017/06/21/apple-goes-after-clones-and-spam-on-the-app-store/feed/
# https://techcrunch.com/2017/06/21/snapchat-buys-zenly/?ncid=rss
# https://techcrunch.com/2017/06/21/snapchat-buys-zenly/
# https://techcrunch.com/2017/06/21/snapchat-buys-zenly/feed/
# https://techcrunch.com/2017/06/21/home-robot-kuri-can-now-recognize-pets-see-and-stream-in-hd/?ncid=rss
# https://techcrunch.com/2017/06/21/home-robot-kuri-can-now-recognize-pets-see-and-stream-in-hd/
# https://techcrunch.com/2017/06/21/home-robot-kuri-can-now-recognize-pets-see-and-stream-in-hd/feed/
# https://techcrunch.com/2017/06/21/founders-corner-wealthfronts-andy-rachleff-on-growing-a-business/?ncid=rss
# https://techcrunch.com/2017/06/21/founders-corner-wealthfronts-andy-rachleff-on-growing-a-business/
# https://techcrunch.com/2017/06/21/founders-corner-wealthfronts-andy-rachleff-on-growing-a-business/feed/
# https://techcrunch.com/2015/07/12/clinton-uber/
# https://techcrunch.com/2015/01/13/google-domains-launches-to-all-in-u-s-with-support-for-blogger-integration-templates-and-more-domain-endings/
# https://techcrunch.com/2014/12/10/youtube-offline-india-indonesia-philippines/
# https://techcrunch.com/2014/06/12/cloudflare-teams-up-with-15-ngos-to-protect-citizen-journalists-and-activists-from-ddos-attacks/
# https://techcrunch.com/2014/03/26/timehop-brings-its-mobile-time-machine-to-android/
# https://techcrunch.com/2014/02/07/firefoxs-chrome-like-australis-redesign-arrives-in-aurora-release-channel/
# https://techcrunch.com/2014/01/01/motorolas-flagship-moto-x-gets-a-permanent-price-cut/
# https://techcrunch.com/2013/12/04/smartcharge-wants-you-not-to-notice-power-outages-at-least-until-the-milk-starts-to-stink/
# https://techcrunch.com/2013/11/30/team-paul-skiing/
# https://techcrunch.com/2013/11/27/microsoft-brings-xbox-video-to-the-web-ahead-of-windows-phone-forgets-hd-playback/
# https://techcrunch.com/2013/11/19/nokia-soft-ly/
# https://techcrunch.com/2013/11/15/ifixit-reveals-the-ps4-is-beautiful-inside-and-out/
# https://techcrunch.com/2013/11/01/bing-renews-its-partnership-with-twitter-keeps-access-to-firehose-feed/
# https://techcrunch.com/2013/11/01/the-first-instagram-ad-has-been-spotted-in-the-wild/
# https://techcrunch.com/2013/10/31/apple-microsoft-backed-rockstar-consortium-sues-google-samsung-over-7-nortel-patents/
# https://techcrunch.com/2013/10/31/calls-to-limit-speech-in-the-snowden-era-underscore-the-importance-of-a-free-press/
# https://techcrunch.com/2013/10/31/being-a-cio-at-tesla-motors-a-startup-that-builds-cars-and-its-own-it/
# https://techcrunch.com/2013/10/28/apple-sends-out-set-of-slick-mac-pro-posters-to-some-journalists/
# https://techcrunch.com/2013/10/23/funding-circle/
# https://techcrunch.com/video/apps/
# https://techcrunch.com/video/bullish/
# https://techcrunch.com/video/crunchreport/
# https://techcrunch.com/events/disrupt-ny-2017/video/
# https://techcrunch.com/video/judah-vs-the-machines/
# https://techcrunch.com/video/gadgets/
# https://techcrunch.com/video/interviews/
# https://techcrunch.com/video/tctv-news/
# https://techcrunch.com/video/reviews/
# https://techcrunch.com/video/features/
# https://techcrunch.com/video/all/
# https://techcrunch.com/2017/06/21/dont-cry-for-me-ubertina/
# https://techcrunch.com/video/uber-ceo-travis-kalanick-resigns-crunch-report/594af8a692fdde0149973b50/
# https://techcrunch.com/video/bullish-sex-and-tech/5949a5309efa895ca0da3aba/
# https://techcrunch.com/video/uber-adds-tipping-crunch-report/59499f338c08e02ab3451acc/
# https://techcrunch.com/video/humotech-uses-robotics-to-fit-amputees-with-prosthetics-feet/594969f192fdde014995524e/
# https://techcrunch.com/video/pokemon-go-big-summer-update-crunch-report/594856d2e0fa172a9d2a58f7/
# https://techcrunch.com/video/pokemon-go-is-getting-a-big-summer-update/59474c8b9e45103e2f1247bc/
# https://techcrunch.com/video/doug-records-his-own-voice-in-waze/59447e339efa895f7134defc/
# https://techcrunch.com/video/amazon-bids-to-buy-whole-foods-for-13-7-billion-crunch-report/5944649cf3bdc90c33feeb92/
# https://techcrunch.com/video/ask-e3-future-of-mobile-gaming/5944353a83b51f62ba6ee4d2/
# https://techcrunch.com/video/e3-nintendos-new-releases-of-nostalgic-games/5943494f83b51f62ba6d8f93/
# https://techcrunch.com/video/twitter-redesigns-desktop-and-mobile-crunch-report/5943145db90afb45de2faaa1/
# https://techcrunch.com/video/behind-the-new-call-of-duty-wwii/5942f73f85eb423a9aec1d6d/
# https://techcrunch.com/video/spheros-spider-man/59422a9485eb42123cbe7d33/
# https://techcrunch.com/video/e3-super-mario-odyssey-on-nintendo-switch/5941ccfcb90afb20229e55a4/
# https://techcrunch.com/video/element-raises-102-million-crunch-report/5941c575e0fa1736179570ea/
# https://techcrunch.com/video/e3-new-games-on-htc-vive/5941a7e69e45101c03b16f20/
# https://techcrunch.com/video/e3-what-is-the-future-of-vr/594182e8b90afb20229d1fd2/
# https://techcrunch.com/video/uber-ceo-takes-leave-of-absence-crunch-report/594070199efa895ab346e6d3/
# https://techcrunch.com/video/re2s-bomb-defusing-robots-mirror-human-movement/594061f9b90afb2ef5f7e324/
# https://techcrunch.com/video/xbox-one-x-is-the-hardcore-gaming-console-we-were-expecting/59401658f3bdc97b6be8490f/
# https://techcrunch.com/video/eeros-new-hardware/593f2d6c8c08e04d1de776fc/
# https://techcrunch.com/video/microsoft-reveals-the-xbox-one-x-crunch-report/593f14ac92fdde3f18e663a7/
# https://techcrunch.com/video/assassins-creed-origins-exclusively-on-xbox-one-x/593f0ecfc214e323a75f5e6e/
# https://techcrunch.com/video/microsoft-unveils-the-xbox-one-x/593ec188e0fa177b0c4e3054/
# https://techcrunch.com/video/best-chat-fiction-apps/593aff699efa890b92689b95/
# https://www.crunchboard.com/jobs/2243735-sr-ruby-platform-engineer-up-to-170k-at-chief-people
# https://www.crunchboard.com/jobs/2243478-software-architect-at-cerner-corporation
# https://www.crunchboard.com/jobs/2243475-software-engineer-at-cerner-corporation
# https://www.crunchboard.com/jobs/2243471-entry-level-software-engineer-at-cerner-corporation
# https://www.crunchboard.com/jobs/2240351-director-of-growth-at-the-social-edge
# https://techcrunch.com/events/meetup-pitch-off-tel-aviv-2016-2/
# https://techcrunch.com/events/12th-annual-summer-party-at-august-capital/
# https://www.crunchbase.com/category/news/db01a2011e4757b3c3cca63eb94e3878?utm_source=crunchbase&utm_medium=export&utm_campaign=crunchbase_tc_river
# https://techcrunch.com/2017/06/22/elastic-enters-apm-space-with-opbeat-acquisition/?ncid=mobilenavtrend
# https://techcrunch.com/2017/06/22/sean-parker-has-left-spotifys-board-padmasree-warrior-thomas-staggs-join-in-lead-up-to-ipo/?ncid=mobilenavtrend
# https://techcrunch.com/2017/06/22/sign-up-for-2-4-1-tickets-to-disrupt-berlin-by-june-29/?ncid=mobilenavtrend
# https://techcrunch.com/2017/06/22/aproplan/?ncid=mobilenavtrend
# https://techcrunch.com/2017/06/21/jd-com-invests-397m-into-luxury-marketplace-farfetch-as-part-of-a-new-strategic-partnership/?ncid=mobilenavtrend
# https://techcrunch.com/2017/06/21/chinas-tantan-raises-70-million/?ncid=mobilenavtrend
# https://techcrunch.com/2017/06/21/facebook-is-testing-a-feature-to-prevent-profile-pictures-being-abused-by-other-users/?ncid=mobilenavtrend
# https://techcrunch.com/2017/06/21/etsy-will-cut-15-percent-of-its-workforce-in-a-new-round-of-layoffs/?ncid=mobilenavtrend
# https://techcrunch.com/2017/06/21/kalanick-is-out-but-ubers-vcs-royally-screwed-up-too-say-industry-watchers/?ncid=mobilenavtrend
# https://techcrunch.com/2017/06/21/bill-gurley-to-leave-ubers-board-of-directors/?ncid=mobilenavtrend
# http://techcrunch.tumblr.com/post/143608822104/now-you-can-get-the-windows-next-word-predicting
# http://techcrunch.tumblr.com/post/143608822104/now-you-can-get-the-windows-next-word-predicting#notes
# http://techcrunch.tumblr.com/post/143559434400/disney-launches-marvel-battlegrounds-a-new
# http://techcrunch.tumblr.com/post/143559434400/disney-launches-marvel-battlegrounds-a-new#notes
# http://techcrunch.tumblr.com/post/143508727597/nasa-announced-that-it-will-send-its-next-lander
# http://techcrunch.tumblr.com/post/143508727597/nasa-announced-that-it-will-send-its-next-lander#notes
# http://techcrunch.tumblr.com/post/143457603215/technology-destroying-jobs-is-something-most
# http://techcrunch.tumblr.com/post/143457603215/technology-destroying-jobs-is-something-most#notes
# http://techcrunch.tumblr.com/post/143405705064/drones-are-hard-to-use-but-they-have-potential
# http://techcrunch.tumblr.com/post/143405705064/drones-are-hard-to-use-but-they-have-potential#notes
# http://techcrunch.tumblr.com/post/143398153109/a-list-containing-hundreds-of-spotify-account
# http://techcrunch.tumblr.com/post/143398153109/a-list-containing-hundreds-of-spotify-account#notes
# http://techcrunch.tumblr.com/post/143398071189/university-of-florida-held-the-worlds-first
# http://techcrunch.tumblr.com/post/143398071189/university-of-florida-held-the-worlds-first#notes
# http://techcrunch.tumblr.com/post/143352102578/we-looked-at-the-top-100-venture-firms-globally-to
# http://techcrunch.tumblr.com/post/143352102578/we-looked-at-the-top-100-venture-firms-globally-to#notes
# http://techcrunch.tumblr.com/post/143295928419/leeco-wheels-out-its-own-self-driving-electric
# http://techcrunch.tumblr.com/post/143295928419/leeco-wheels-out-its-own-self-driving-electric#notes
# http://techcrunch.tumblr.com/post/143243575001/we-just-launched-a-personalized-news
# http://techcrunch.tumblr.com/post/143243575001/we-just-launched-a-personalized-news#notes
# http://techcrunch.tumblr.com/tagged/news
# https://techcrunch.com/timeline/waymo-v-uber-everything-you-need-to-know/
# https://techcrunch.com/timeline/techcrunch-2016-year-in-review/
# https://techcrunch.com/timeline/the-top-artificial-intelligence-stories-of-2016/
# https://techcrunch.com/timeline/the-top-biotech-stories-of-2016/
# https://techcrunch.com/timeline/the-top-15-events-that-happened-in-space-in-2016/
# https://techcrunch.com/timeline/pebbles-story-from-kickstarter-sensation-to-fitbit-acquisition/
# https://techcrunch.com/timeline/the-rise-and-fall-of-the-galaxy-note-7/
# https://techcrunch.com/timeline/the-many-names-of-apples-operating-systems-from-system-1-to-macos-sierra/
# https://techcrunch.com/timeline/a-timeline-of-apples-iphone-unlocking-fight-with-the-fbi/
# https://techcrunch.com/timeline/a-brief-history-of-twitters-executive-departures/
# https://techcrunch.com/video/gillmor-gang/
# https://techcrunch.com/video/gillmor-gang-abstraction-of-justice/594567cce0fa1757eb2757fa/
# https://techcrunch.com/video/judah-vs-tedious-tasks-robot/591f16ab85eb426399e14c0f/
# https://techcrunch.com/video/makerbot-ceo-nadav-goshen-on-3d-printing/58fa5fd0b90afb2ed042dfb7/
# https://techcrunch.com/video/samsung-galaxy-s8-and-s8-review/58f58ffc955a317b117bc15a/
# https://techcrunch.com/video/down-round/
# https://techcrunch.com/video/the-down-round-entire-series/58223901134aa155205491b2/
# https://techcrunch.com/video/trust-disrupted/
# https://techcrunch.com/video/co-opt-vs-disrupt-truth-disrupted-bitcoin-and-the-blockchain-s1e6/57f587195095497719f427c4/
# https://techcrunch.com/category/video/feed/
# https://techcrunch.com/2017/06/08/softbank-is-buying-robotics-firm-boston-dynamics-and-schaft-from-alphabet/
# https://techcrunch.com/2017/05/03/go-jek-tencent-1-2-billion/
# https://techcrunch.com/video/uber-ceo-travis-kalanick-resigns-crunch-report/594af8a692fdde0149973b50/?ncid=rightrail_cr
# https://techcrunch.com/video/crunchreport/?ncid=rightrail_crmore
# http://techcrunch.cn/2017/06/13/emil-michael-ubers-svp-of-business-has-left-the-company/#disqus_thread
# http://techcrunch.cn/2017/06/13/comscore-cord-cutters-tend-to-have-lower-incomes-than-pay-tv-subscribers-watch-less-television/#disqus_thread
# http://techcrunch.cn/2017/06/05/toyotas-flying-car-project-takes-a-tentative-test-flight/#disqus_thread
# http://techcrunch.cn/2017/06/02/us-approves-social-media-background-checks-for-visa-applicants/#disqus_thread
# http://techcrunch.cn/2017/06/02/onelogin-admits-recent-breach-is-pretty-dang-serious/#disqus_thread
# http://techcrunch.cn/2017/06/02/dji-spark-review/#disqus_thread
# http://techcrunch.cn/2017/06/02/tc-shenzhen-2017-we-young/#disqus_thread
# http://techcrunch.cn/2017/06/01/internet-trends-2017/#disqus_thread
# http://techcrunch.cn/2017/06/01/ntt-data-announces-strategic-investment-in-nosql-database-provider-marklogic/#disqus_thread
# http://techcrunch.cn/2017/05/27/mozilla-2017-goal-for-a-healthy-internet/#disqus_thread
# http://techcrunch.cn/2017/05/27/httpstechcrunch-com20170526reid-hoffman-bill-gates-sam-altman-invest-30-million-in-change-org/
# http://techcrunch.cn/2017/05/27/httpstechcrunch-com20170526reid-hoffman-bill-gates-sam-altman-invest-30-million-in-change-org/#disqus_thread
# http://techcrunch.cn/2017/05/26/career-coaching-service-paragon-one-gets-1-9m-seed-funding-from-investors-including-y-combinator/
# http://techcrunch.cn/2017/05/26/career-coaching-service-paragon-one-gets-1-9m-seed-funding-from-investors-including-y-combinator/#disqus_thread
# http://techcrunch.cn/2017/05/26/mark-zuckerberg-harvard/
# http://techcrunch.cn/2017/05/26/mark-zuckerberg-harvard/#disqus_thread
# http://techcrunch.cn/2017/05/26/readdle-adds-a-clever-drag-and-drop-feature-for-moving-files-between-its-ipad-productivity-apps/
# http://techcrunch.cn/2017/05/26/readdle-adds-a-clever-drag-and-drop-feature-for-moving-files-between-its-ipad-productivity-apps/#disqus_thread
# http://techcrunch.cn/2017/05/26/tennis-star-serena-williams-joins-surveymonkeys-board/
# http://techcrunch.cn/2017/05/26/tennis-star-serena-williams-joins-surveymonkeys-board/#disqus_thread
# http://techcrunch.cn/2017/05/26/hbos-silicon-valley-gets-renewed-for-fifth-season-erlich-bachman-wont-return/
# http://techcrunch.cn/2017/05/26/hbos-silicon-valley-gets-renewed-for-fifth-season-erlich-bachman-wont-return/#disqus_thread
# http://techcrunch.cn/2017/05/23/toyota-pushes-into-blockchain-tech-to-enable-the-next-generation-of-cars/
# http://techcrunch.cn/2017/05/23/toyota-pushes-into-blockchain-tech-to-enable-the-next-generation-of-cars/#disqus_thread
# http://techcrunch.cn/2017/05/23/heres-the-teaser-for-the-mini-drone-dji-is-announcing-this-week/
# http://techcrunch.cn/2017/05/23/heres-the-teaser-for-the-mini-drone-dji-is-announcing-this-week/#disqus_thread
# http://techcrunch.cn/2017/05/19/with-mixhalo-incubus-guitarist-mike-einziger-aims-to-deliver-studio-quality-sound-at-live-events/
# http://techcrunch.cn/2017/05/19/with-mixhalo-incubus-guitarist-mike-einziger-aims-to-deliver-studio-quality-sound-at-live-events/#disqus_thread
# http://techcrunch.cn/2017/05/19/defend-net-neutrality/
# http://techcrunch.cn/2017/05/19/defend-net-neutrality/#disqus_thread
# http://jp.techcrunch.com/2017/06/22/mercari-cbo-john-lagerling/
# http://jp.techcrunch.com/2017/06/22/20170621google-glass-is-apparently-still-around-and-just-got-its-first-update-in-nearly-three-years/
# http://jp.techcrunch.com/2017/06/22/woody-fundraised/
# http://jp.techcrunch.com/2017/06/21/20170621swift-creator-departs-tesla-after-just-six-months/
# http://jp.techcrunch.com/2017/06/21/20170620uber-ceo-travis-kalanick-resigns/
# http://jp.techcrunch.com/2017/06/21/engadget-reenter-japan/
# http://jp.techcrunch.com/2017/06/21/aising-raised-200mil-yen/
# http://jp.techcrunch.com/2017/06/21/report-mobile-payment/
# http://jp.techcrunch.com/2017/06/21/20170620uber-adds-tipping/
# http://jp.techcrunch.com/2017/06/21/20170620kik-ceo-claims-an-ico-is-better-than-venture-fundraisingncidmobilenavtrend/
# http://jp.techcrunch.com/2017/06/21/pulit-second-fundrasing/
# http://jp.techcrunch.com/2017/06/21/20170620boom-has-orders-for-76-of-its-future-supersonic-passenger-jets/
# http://jp.techcrunch.com/2017/06/21/20170620amazon-prime-wardrobe/
# http://jp.techcrunch.com/2017/06/20/20170620google-launches-its-ai-powered-jobs-search-engine/
# http://jp.techcrunch.com/2017/06/20/engadget-pokemon-go-update/
# http://jp.techcrunch.com/2017/06/20/moneyfoward-new-subsidiary/
# http://jp.techcrunch.com/2017/06/20/japan-foodie-fund-raise/
# http://jp.techcrunch.com/2017/06/20/20170619will-amazon-become-a-force-in-fintech/
# http://jp.techcrunch.com/2017/06/20/20170619researchers-train-drones-to-use-wi-fi-to-look-through-walls/
# http://jp.techcrunch.com/2017/06/20/20170619tensor2tensor/
# http://jp.techcrunch.com/2017/06/22/20170621facebook-open-sources-its-it-management-tool-for-distributing-adobes-creative-cloud-tools-to-employees/#comments
# http://jp.techcrunch.com/2017/06/22/20170621chinas-tantan-raises-70-million/#comments
# http://jp.techcrunch.com/2017/06/22/20170621re2-tapped-by-u-s-air-force-to-build-robot-pilots-to-fly-traditional-aircraft/#comments
# http://jp.techcrunch.com/2017/06/22/20170621snapchat-buys-zenly/#comments
# http://jp.techcrunch.com/2017/06/22/20170621facebook-is-testing-a-feature-to-prevent-profile-pictures-being-abused-by-other-users/#comments
# http://jp.techcrunch.com/2017/06/22/eight-corporate-page/#comments
# http://jp.techcrunch.com/2017/06/22/20170620apple-releases-new-iphone-ad-focused-on-the-memories-feature/#comments
# http://jp.techcrunch.com/2017/06/22/20170621textio-20m/#comments
# http://jp.techcrunch.com/2017/06/22/20170621segas-new-sega-forever-collection-brings-classic-games-to-mobile-for-free/#comments
# http://jp.techcrunch.com/2017/06/22/20170621watch-former-apple-engineers-and-scott-forstall-discuss-the-creation-of-the-iphone/#comments
# http://jp.techcrunch.com/2017/06/22/20170621home-robot-kuri-can-now-recognize-pets-see-and-stream-in-hd/
# http://jp.techcrunch.com/2017/06/22/20170621home-robot-kuri-can-now-recognize-pets-see-and-stream-in-hd/#comments
# http://jp.techcrunch.com/2017/06/22/mercari-cbo-john-lagerling/#comments
# http://jp.techcrunch.com/2017/06/22/20170621google-glass-is-apparently-still-around-and-just-got-its-first-update-in-nearly-three-years/#comments
# http://jp.techcrunch.com/2017/06/22/woody-fundraised/#comments
# http://jp.techcrunch.com/2017/06/22/20170620netflix-debuts-choose-your-own-adventure-stories-for-kidsncidrss/
# http://jp.techcrunch.com/2017/06/22/20170620netflix-debuts-choose-your-own-adventure-stories-for-kidsncidrss/#comments
# http://jp.techcrunch.com/2017/06/22/20170620fetch-launches-self-service-truck-rentals-to-help-you-move-the-big-stuff/
# http://jp.techcrunch.com/2017/06/22/20170620fetch-launches-self-service-truck-rentals-to-help-you-move-the-big-stuff/#comments
# http://jp.techcrunch.com/2017/06/22/20170620final-one-credit-card-to-rule-them-all/
# http://jp.techcrunch.com/2017/06/22/20170620final-one-credit-card-to-rule-them-all/#comments
# http://jp.techcrunch.com/2017/06/22/20170621spotify-now-lets-you-build-playlists-with-friends-inside-messenger/
# http://jp.techcrunch.com/2017/06/22/20170621spotify-now-lets-you-build-playlists-with-friends-inside-messenger/#comments
# http://jp.techcrunch.com/2017/06/22/20170621dont-cry-for-me-ubertina/
# http://jp.techcrunch.com/2017/06/22/20170621dont-cry-for-me-ubertina/#comments
# http://jp.techcrunch.com/2017/06/22/20170621growbots-raises-2-5m-for-its-machine-learning-based-sales-automation-platform/
# http://jp.techcrunch.com/2017/06/22/20170621growbots-raises-2-5m-for-its-machine-learning-based-sales-automation-platform/#comments
# https://techcrunch.com/gallery/nintendos-upcoming-switch-titles-include-metroid-mario-kirby-xenoblade-and-an-in-progress-pokemon-rpg/
# https://techcrunch.com/gallery/sony-updates-its-leading-playstation-franchises-with-new-uncharted-gran-turismo-god-of-war-and-others/
# https://techcrunch.com/gallery/ubisofts-e3-2017-games-include-assassins-creed-origins-far-cry-5-the-crew-2-and-more/
# https://techcrunch.com/gallery/bethesda-announces-skyrim-for-the-switch-plus-vr-versions-of-fallout-4-and-doom/
# https://techcrunch.com/gallery/ea-announces-star-wars-battlefront-ii-madden-18-and-more-new-games-from-e3-2017/
# https://techcrunch.com/gallery/worst-volume-controls/
# https://techcrunch.com/gallery/here-are-the-most-well-designed-apps-of-2017-as-picked-by-apple/
# https://techcrunch.com/gallery/everything-apple-announced-at-its-wwdc-keynote/
# https://techcrunch.com/gallery/internet-trends-2017/
# https://techcrunch.com/gallery/the-20-most-memorable-quotes-of-disrupt-new-york-2017/
# https://techcrunch.com/gallery/our-favorite-startups-from-alchemist-accelerator-batch-15/
# https://techcrunch.com/gallery/everything-google-announced-at-its-google-io-keynote/
# https://techcrunch.com/gallery/top-six-tips-to-help-avoid-ransomware/
# https://techcrunch.com/gallery/our-favorite-startups-from-500-startups-20th-class/
# https://techcrunch.com/gallery/everything-that-happened-at-microsoft-build-day-1/
# https://techcrunch.com/gallery/these-11-technologies-want-to-hack-your-brains/
# https://techcrunch.com/gallery/imagining-five-retro-technologies-as-startup-pitches/
# https://techcrunch.com/gallery/12-tech-inspired-mothers-day-gifts/
# https://techcrunch.com/gallery/page/2/

# %%
# Create a dictionary from the tech company tickers, with none as the value of the keys
article_dict = dict.fromkeys(ticker_tech_comp, None)

# %% [markdown]
# To determine if an article is talking about a specific company, I run through the company urls which contains the article's title. If the company name is in the title, then that means that the article is about that company

# %%
# Fill the dictionary with the first related news article 
for article in techcrunch_paper.articles:
    for company, company_ticker in zip(tech_comp, ticker_tech_comp):
        # Appears to extract english and japanese articles, we only want english
        if company in article.url and "jp" not in article.url: 
            if(article_dict[company_ticker] == None):
                article_dict[company_ticker] = article

# %%
article_dict
# Out:
# {'AAPL': <newspaper.article.Article at 0x11d978630>,
#  'AMZN': <newspaper.article.Article at 0x11d98bbe0>,
#  'FB': <newspaper.article.Article at 0x11d99b278>,
#  'GOOG': <newspaper.article.Article at 0x124e20470>,
#  'MSFT': <newspaper.article.Article at 0x11d992e10>}

# %%
# Download the articles and parse through them so we can use the text
for key in article_dict:
    article_dict[key].download()
    article_dict[key].parse()
# Out:
# Building prefix dict from /Users/Angus/anaconda/lib/python3.6/site-packages/jieba/dict.txt ...
# Loading model from cache /var/folders/l7/r9r7m7qn5mz1d267mf3jqfgm0000gn/T/jieba.cache
# Loading model cost 1.5296659469604492 seconds.
# Prefix dict has been built succesfully.

# %% [markdown]
# Next we want to create a vocabularly list for each of the words used in the article.
# We will put this in a dictionary with an index associated with each of the vocab keys

# %% [markdown]
# Vocab for each of the the articles individually (Need to ask Henry)
# ----
# Should I be using the spacy vectors

# %% [markdown]
# # Create a dictionary from the tech company tickers, with none as the value of the keys
# vocab_dict = dict.fromkeys(ticker_tech_comp, None)

# %% [markdown]
# # Tokenize each of the articles and create a sorted unique vocabulary list for each company
# for key in vocab_dict:
#     vocab_dict[key] = sorted(set(tokenize(tech_dict[key].text)))
#     vocab_dict[key] = dict((vocab, i + 1) for i, vocab in enumerate(vocab_dict[key]))

# %% [markdown]
# Vocab for all of the the articles (Need to ask Henry)
# ----
# Only concern is I have to retrain every time i scrape new articles?

# %%
# Run through each article and append new vocab in vocab list
vocab = set()
for ticker in ticker_tech_comp:
    vocab |= set((tokenize(article_dict[ticker].text)))
# Out:
# /Users/Angus/anaconda/lib/python3.6/re.py:212: FutureWarning: split() requires a non-empty pattern match.
#   return _compile(pattern, flags).split(string, maxsplit)

# %%
# Put in a dictionary with an index for each of the vocabulary
# Reserve 0 for masking via pad_sequences
vocab = sorted(vocab)
vocab_id = dict((word, i + 1) for i, word in enumerate(vocab))
vocab_size = len(vocab) + 1

# %%
# Get the max article length for tokenize -> Spacy does different parsing so lengths may differ
article_len = []
for ticker in ticker_tech_comp:
    article_len.append(len(tokenize(article_dict[ticker].text)))

article_maxlen = max(article_len)
# Out:
# /Users/Angus/anaconda/lib/python3.6/re.py:212: FutureWarning: split() requires a non-empty pattern match.
#   return _compile(pattern, flags).split(string, maxsplit)

# %%
def vectorize_stories(article, vocab_id, article_maxlen):
    word_id = []
    for word in article:
        word_id.append(vocab_id[word]) 
    return pad_sequences([word_id], maxlen=article_maxlen)

# %%
# Create a dictionary from the tech company tickers, with none as the value of the keys
article_vectorized_dict = dict.fromkeys(ticker_tech_comp, None)

for ticker in ticker_tech_comp:
    article_vectorized_dict[ticker] = vectorize_stories(tokenize(article_dict[ticker].text), vocab_id, article_maxlen)

article_vectorized_dict
# Out:
# /Users/Angus/anaconda/lib/python3.6/re.py:212: FutureWarning: split() requires a non-empty pattern match.
#   return _compile(pattern, flags).split(string, maxsplit)
# {'AAPL': array([[ 55, 724,  39, ..., 547, 556,  10]], dtype=int32),
#  'AMZN': array([[  0,   0,   0, ..., 400, 627,  10]], dtype=int32),
#  'FB': array([[  0,   0,   0, ..., 707, 558,  10]], dtype=int32),
#  'GOOG': array([[  0,   0,   0, ..., 851,  93, 175]], dtype=int32),
#  'MSFT': array([[ 0,  0,  0, ..., 52, 22, 78]], dtype=int32)}

# %%
#df = pd.read_csv('final_stock_features_dfs/{}.csv'.format('FB'), index_col=0)
df = pd.read_csv('final_stock_features_dfs/{}.csv'.format('FB'))

df
# Out:
#       Perc_Change_1d  100_mov_avg  Open_Prev_1d  High_Prev_1d  Low_Prev_1d  \
# 0           0.006053    38.000000           NaN           NaN          NaN
# 1          -0.109861    38.115000           NaN           NaN          NaN
# 2          -0.089039    36.753333         42.05         45.00        38.00
# 3           0.032258    35.315000         36.53         36.66        33.00
# 4           0.032188    34.652000         32.61         33.59        30.94
# 5          -0.033909    34.381667         31.37         32.50        31.36
# 6          -0.096208    34.028571         32.95         33.21        31.77
# 7          -0.022538    33.380000         32.90         32.95        31.11
# 8           0.050018    32.803333         31.48         31.69        28.65
# 9          -0.063514    32.483000         28.70         29.55        27.86
# 10         -0.029582    32.050000         28.54         29.67        26.83
# 11         -0.038290    31.620833         28.89         29.15        27.39
# 12          0.036336    31.178462         27.20         27.65        26.44
# 13         -0.018650    30.866429         26.70         27.76        25.75
# 14          0.030027    30.562667         26.07         27.17        25.52
# 15         -0.003690    30.346250         27.00         27.35        26.15
# 16          0.014815    30.149412         26.55         27.76        26.44
# 17         -0.004745    29.996667         27.18         28.07        26.84
# 18          0.037404    29.853158         27.48         27.77        26.96
# 19          0.060799    29.775000         27.66         28.10        27.10
# 20          0.046651    29.786190         27.65         28.32        27.38
# 21          0.015918    29.860000         28.50         30.10        28.35
# 22         -0.009715    29.949130         29.96         32.08        29.41
# 23          0.007595    30.017917         31.54         32.18        30.70
# 24          0.038003    30.090800         31.92         31.93        31.15
# 25         -0.029955    30.204615         31.67         32.50        31.51
# 26          0.032439    30.273333         32.41         33.45        32.06
# 27         -0.026284    30.374286         32.86         33.02        31.55
# 28         -0.026993    30.438276         32.69         33.44        32.50
# 29         -0.008291    30.469000         32.46         32.90        31.90
# ...              ...          ...           ...           ...          ...
# 1252       -0.001663   135.106300        151.49        152.59       150.21
# 1253        0.001933   135.401000        150.23        150.52       148.86
# 1254       -0.000931   135.705600        150.31        150.65       149.41
# 1255       -0.002730   136.015100        150.40        150.46       149.63
# 1256       -0.032915   136.322000        150.17        151.48       149.77
# 1257        0.019399   136.580100        150.11        150.21       149.03
# 1258        0.002709   136.882700        148.00        148.67       144.42
# 1259        0.001216   137.190600        144.72        148.15       144.51
# 1260       -0.001147   137.492900        148.44        149.39       147.96
# 1261        0.013305   137.804400        148.08        148.59       147.69
# 1262        0.012797   138.141300        148.52        148.81       147.25
# 1263        0.001119   138.510400        148.51        150.23       148.42
# 1264        0.001643   138.863100        150.30        152.59       149.95
# 1265       -0.006038   139.200000        152.23        152.25       151.15
# 1266        0.000462   139.507900        151.97        152.90       151.64
# 1267        0.013727   139.789100        152.70        153.35       151.09
# 1268        0.000130   140.076200        151.75        152.29       150.30
# 1269       -0.005337   140.369000        151.85        153.63       151.30
# 1270        0.002029   140.636200        153.64        154.71       153.41
# 1271        0.010384   140.901200        153.41        154.52       152.48
# 1272       -0.033030   141.164900        153.27        153.75       152.34
# 1273       -0.007754   141.382200        154.08        154.73       153.10
# 1274        0.015090   141.587400        154.77        155.59       146.61
# 1275       -0.002854   141.818700        148.17        149.20       144.56
# 1276       -0.002995   142.050800        150.15        151.18       148.90
# 1277        0.005607   142.259500        151.26        152.40       149.05
# 1278        0.014804   142.472200        147.67        150.04       146.37
# 1279       -0.004056   142.686100        149.59        150.83       148.60
# 1280        0.010903   142.880800        151.71        153.57       151.71
# 1281             NaN   143.098100        152.88        153.84       152.21
#
#       Close_Prev_1d  Volume_Prev_1d
# 0               NaN             NaN
# 1             38.00             0.0
# 2             38.23     580587742.0
# 3             34.03     168309831.0
# 4             31.00     102053826.0
# 5             32.00      73721135.0
# 6             33.03      50275879.0
# 7             31.91      37189630.0
# 8             28.84      78060799.0
# 9             28.19      57267867.0
# 10            29.60     111639200.0
# 11            27.72      41855500.0
# 12            26.90      35230290.0
# 13            25.87      42473262.0
# 14            26.81      61487019.0
# 15            26.31      26167757.0
# 16            27.10      38033420.0
# 17            27.00      28225887.0
# 18            27.40      15822414.0
# 19            27.27      17118672.0
# 20            28.29      16854124.0
# 21            30.01      43563739.0
# 22            31.41      42978209.0
# 23            31.91      30848913.0
# 24            31.60      15558921.0
# 25            31.84      21875228.0
# 26            33.05      74833976.0
# 27            32.06      24352818.0
# 28            33.10      24858611.0
# 29            32.23      28599506.0
# ...             ...             ...
# 1252         150.48      17453859.0
# 1253         150.29      12080650.0
# 1254         150.04      11841864.0
# 1255         150.33       9598229.0
# 1256         150.19      15064664.0
# 1257         149.78      14550830.0
# 1258         144.85      28300050.0
# 1259         147.66      23031566.0
# 1260         148.06      16187892.0
# 1261         148.24      12586712.0
# 1262         148.07      12817837.0
# 1263         150.04      17940668.0
# 1264         151.96      19891352.0
# 1265         152.13      14996185.0
# 1266         152.38      13226007.0
# 1267         151.46      18023917.0
# 1268         151.53      14530600.0
# 1269         153.61      16854365.0
# 1270         153.63      12520387.0
# 1271         152.81      13457119.0
# 1272         153.12      12066657.0
# 1273         154.71      17799449.0
# 1274         149.60      35577676.0
# 1275         148.44      33170180.0
# 1276         150.68      20483350.0
# 1277         150.25      20808759.0
# 1278         149.80      18994152.0
# 1279         150.64      22882417.0
# 1280         152.87      19026462.0
# 1281         152.25      14743853.0
#
# [1282 rows x 7 columns]

# %%
numStockDates = len(df)

# %%
df_fb = pd.DataFrame(article_vectorized_dict['FB'])
df_fb = df_fb.append(list(article_vectorized_dict['FB'])*(numStockDates-1),ignore_index=True)

# %%
final_df = pd.concat([df, df_fb], axis=1)

# %%
final_df = final_df.iloc[2:]
final_df.dropna(inplace=True)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(final_df.drop(["Perc_Change_1d"], axis=1), final_df["Perc_Change_1d"], test_size=0.33, random_state=42)

# %%
# Split the x_train and x_test into the articles and the financial features to be put into the model
# Training Set
x_train_stock_features = x_train.iloc[:,:6]
x_train_articles = x_train.iloc[:,6:]
# Testing Set
x_test_stock_features = x_test.iloc[:,:6]
x_test_articles = x_test.iloc[:,6:]

# %%
from sklearn import preprocessing
x_train_stock_features_normalized = preprocessing.scale(x_train_stock_features) 
x_test_stock_features_normalized = preprocessing.scale(x_test_stock_features)

# %%
x_train_stock_features_normalized
# Out:
# array([[-0.17313751,  0.00461614, -0.0079307 , -0.01365012, -0.03053764,
#         -0.20058973],
#        [ 0.16216197,  0.14422263,  0.13780722,  0.15867996,  0.13892046,
#         -0.74748437],
#        [-1.28213343, -1.0821143 , -1.03826383, -1.07341434, -1.02950358,
#          3.94658823],
#        ...,
#        [ 1.43355598,  1.10444287,  1.07793406,  0.98481194,  0.99588679,
#          0.35712927],
#        [ 0.49016933,  0.57011409,  0.56850315,  0.53780613,  0.52307778,
#         -0.25018732],
#        [ 1.42895871,  1.18040137,  1.22080414,  1.19502833,  1.23490639,
#         -0.58032435]])

# %%
x_test_stock_features_normalized
# Out:
# array([[ 1.634425  ,  1.77502562,  1.76497586,  1.79480739,  1.79039209,
#         -0.81690989],
#        [ 1.45032209,  1.44523713,  1.43785953,  1.46398065,  1.43698063,
#         -0.81104998],
#        [-0.20992976, -0.08833121, -0.10271118, -0.08683489, -0.09308612,
#         -0.41406481],
#        ...,
#        [-0.57916285, -0.58275468, -0.56872931, -0.56220265, -0.55176907,
#          0.23442301],
#        [-1.22966475, -1.31570442, -1.32984921, -1.31673807, -1.32989656,
#         -0.04935758],
#        [-1.13190807, -1.30740785, -1.29447831, -1.30525828, -1.28633594,
#          0.64068029]])

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import LSTM
from keras.optimizers import Adam
from keras.layers import recurrent
from keras import layers
from keras.models import Model

EMBED_HIDDEN_SIZE = 50

RNN = recurrent.LSTM

print('Build model...')
# Put articles into an LSTM
articles = layers.Input(shape=(article_maxlen,), dtype='int32')
encoded_articles = layers.Embedding(vocab_size, EMBED_HIDDEN_SIZE)(articles)
encoded_articles = layers.Dropout(0.3)(encoded_articles)
encoded_articles = RNN(EMBED_HIDDEN_SIZE)(encoded_articles)
# Grab Stock Features 
stock_features = layers.Input(shape=(6,))
# Concat the two layers
merged = layers.concatenate([stock_features, encoded_articles])
# Dense with one prediction for the percentage change
pred = layers.Dense(1)(merged)
# Create model
model = Model([articles, stock_features], pred)
model.compile(loss='mean_squared_error',
              optimizer=Adam(lr=0.001),
            )
# Out:
# Build model...

# %%
BATCH_SIZE = 32
EPOCHS = 30

print('Training')

model.fit([x_train_articles.values, x_train_stock_features_normalized], 
          y_train.values,
          batch_size=BATCH_SIZE,
          epochs=EPOCHS,
          validation_split=0.05)

loss = model.evaluate([x_test_articles.values, x_train_stock_features_normalized], 
                      y_test.values,
                      batch_size=BATCH_SIZE)
# Out:
# Training
# Train on 813 samples, validate on 43 samples
# Epoch 1/30
# 224/813 [=======>......................] - ETA: 138s - loss: 0.0098

# %% [markdown]
# Converting each of the articles using the spacy vectors
# ----
# Better for reusing same training model?

# %% [markdown]
# # Create a dictionary from the tech company tickers, with none as the value of the keys
# article_nlp_dict = dict.fromkeys(ticker_tech_comp, None)
#
# # Convert each into a spacy processed text
# for ticker in ticker_tech_comp:
#     article_nlp_dict[ticker] = nlp(tech_dict[ticker].text)

# %% [markdown]
# # Get the max article length for Spacy
# article_len_spacy = []
# for ticker in ticker_tech_comp:
#     article_len_spacy.append(len(article_nlp_dict[ticker]))
#
# article_maxlen_spacy = max(article_len_spacy)

# %% [markdown]
# # Find a way to pad the NLP of the articles to the max length
# article_vector_dict = dict.fromkeys(ticker_tech_comp, None)
# # Vector format for each of the tech companies
# for ticker in ticker_tech_comp:
#     article_vector_dict[ticker] = [word.vector for word in article_nlp_dict[ticker]]
